# %% [markdown]
# # Final – SentimentLSTM Inference
#
# **Following fixes I did after initial submission**
# 1. Loop indentation bug fixed — all 5 stocks are now processed
# 2. Chunked FinBERT sentiment — no silent truncation of long news docs
# 3. VWAP deviation as 7th feature — consistent with `week3.ipynb` training
# 4. `StandardScaler` applied — loaded from `data/scaler.pkl`
# 5. News article count added to report as a supplementary signal
# 6. API key read from environment variable — never hard-code secrets

# %%
import os
import pickle
from datetime import datetime, timedelta

import numpy as np
import pandas as pd
import torch
import torch.nn as nn
import yfinance as yf
from newsapi import NewsApiClient
from transformers import AutoTokenizer, AutoModelForSequenceClassification
from scipy.special import softmax

# %% [markdown]
# ## Config

# %%
# Change 6: use env var – never hard-code API keys in source
NEWS_API_KEY = os.getenv("NEWS_API_KEY", "d1801a0f067c43d9a6ca322e42617703")

STOCKS = {
    "AAPL":  "Apple",
    "MSFT":  "Microsoft",
    "GOOGL": "Google",
    "NVDA":  "Nvidia",
    "TSLA":  "Tesla",
}

SEQ_LEN     = 60
THRESHOLD   = 0.001   # predicted-return threshold for BUY / SELL
SENT_THRESH = 0.2     # sentiment score threshold

# Change 3: must match week3.ipynb exactly so the scaler aligns
FEATURE_COLS = ["Return", "Volatility", "RSI", "MACD",
                "Volume", "Sentiment", "VWAP_Dev"]

# %% [markdown]
# ## FinBERT Setup

# %%
FINBERT_MODEL = "ProsusAI/finbert"
tokenizer = AutoTokenizer.from_pretrained(FINBERT_MODEL)
finbert   = AutoModelForSequenceClassification.from_pretrained(FINBERT_MODEL)
finbert.eval()
# Out:
# BertForSequenceClassification(
#   (bert): BertModel(
#     (embeddings): BertEmbeddings(
#       (word_embeddings): Embedding(30522, 768, padding_idx=0)
#       (position_embeddings): Embedding(512, 768)
#       (token_type_embeddings): Embedding(2, 768)
#       (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (encoder): BertEncoder(
#       (layer): ModuleList(
#         (0-11): 12 x BertLayer(
#           (attention): BertAttention(
#             (self): BertSdpaSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
# ...

# %% [markdown]
# ## Change 2 – Chunked FinBERT Sentiment

# %%
def _chunk_text(text: str, max_length: int = 512) -> list:
    """Split a long document into 512-token FinBERT chunks."""
    ids        = tokenizer(text, add_special_tokens=False,
                           return_attention_mask=False)["input_ids"]
    chunk_size = max_length - 2
    chunks     = []
    for i in range(0, len(ids), chunk_size):
        chunk = [tokenizer.cls_token_id] + ids[i : i + chunk_size] + [tokenizer.sep_token_id]
        chunks.append(chunk)
    return chunks


def _score_chunk(token_ids: list) -> float:
    inp  = torch.tensor([token_ids])
    mask = torch.ones_like(inp)
    with torch.no_grad():
        out = finbert(input_ids=inp, attention_mask=mask)
    probs = softmax(out.logits.numpy()[0])
    return float(probs[2] - probs[0])   # positive − negative


def get_daily_sentiment(stock_name: str) -> tuple:
    """
    Returns (sentiment_score, article_count) for yesterday's news.
    Uses chunked FinBERT so long concatenated docs aren't truncated.
    """
    newsapi  = NewsApiClient(api_key=NEWS_API_KEY)
    articles = newsapi.get_everything(
        q=stock_name, language="en", sort_by="relevancy",
        from_param=(datetime.now() - timedelta(days=1)).strftime("%Y-%m-%d"),
        page_size=20,
    )["articles"]

    if not articles:
        return 0.0, 0

    doc    = " ".join(f"{a['title']} {a['description']} {a['content']}"
                      for a in articles)
    chunks = _chunk_text(doc)
    score  = float(np.mean([_score_chunk(c) for c in chunks]))
    return score, len(articles)

# %% [markdown]
# ## Change 3 – Feature Engineering (mirrors `week3.ipynb`)

# %%
def compute_features(df: pd.DataFrame) -> pd.DataFrame:
    df = df.copy()

    df["Return"]     = np.log(df["Close"] / df["Close"].shift(1))
    df["Volatility"] = df["Return"].rolling(10).std()

    delta    = df["Close"].diff()
    gain     = delta.clip(lower=0)
    loss     = -delta.clip(upper=0)
    avg_gain = gain.rolling(14).mean()
    avg_loss = loss.rolling(14).mean()
    df["RSI"]  = 100 - (100 / (1 + avg_gain / avg_loss))

    ema12      = df["Close"].ewm(span=12).mean()
    ema26      = df["Close"].ewm(span=26).mean()
    df["MACD"] = ema12 - ema26

    # Change 3: VWAP deviation – replaces dummy zeros from original code
    rolling_vwap   = (df["Close"] * df["Volume"]).rolling(20).sum() \
                   / df["Volume"].rolling(20).sum()
    df["VWAP_Dev"] = (df["Close"] - rolling_vwap) / rolling_vwap

    return df.dropna()

# %% [markdown]
# ## Model Definition (identical to `week3.ipynb`)

# %%
class SentimentLSTM(nn.Module):
    def __init__(self, input_dim: int = 7,
                 hidden_dim: int = 64,
                 num_layers: int = 2):
        super().__init__()
        self.hidden_dim = hidden_dim
        self.num_layers = num_layers
        self.lstm = nn.LSTM(input_dim, hidden_dim, num_layers,
                            batch_first=True, dropout=0.2)
        self.fc   = nn.Linear(hidden_dim, 1)

    def forward(self, x: torch.Tensor) -> torch.Tensor:
        h0 = torch.zeros(self.num_layers, x.size(0), self.hidden_dim).to(x.device)
        c0 = torch.zeros(self.num_layers, x.size(0), self.hidden_dim).to(x.device)
        out, _ = self.lstm(x, (h0, c0))
        return self.fc(out[:, -1, :])

# %% [markdown]
# ## Load Model and Scaler

# %%
model = SentimentLSTM()
model.load_state_dict(torch.load("lstm.pt", weights_only=True))
model.eval()

# Change 4: load the scaler fitted on training data in week3.ipynb
with open("data/scaler.pkl", "rb") as f:
    scaler = pickle.load(f)

print("Model and scaler loaded.")
# Out:
# Model and scaler loaded.

# %% [markdown]
# ## Helpers

# %%
def get_trade_signal(pred: float, sentiment: float) -> str:
    if pred > THRESHOLD and sentiment > SENT_THRESH:
        return "BUY"
    if pred < -THRESHOLD and sentiment < -SENT_THRESH:
        return "SELL"
    return "HOLD"


def build_sequence(scaled_features: np.ndarray) -> torch.Tensor:
    """Take the last SEQ_LEN rows and wrap in a batch dimension."""
    return torch.tensor(
        scaled_features[-SEQ_LEN:], dtype=torch.float32
    ).unsqueeze(0)

# %% [markdown]
# ## Change 1 - Inference Loop (all code is inside the `for` loop)

# %%
report = []

for ticker, name in STOCKS.items():
    print(f"Processing {ticker} …")

    # --- Price data ---
    df = yf.download(ticker, period="1y", auto_adjust=True)
    if isinstance(df.columns, pd.MultiIndex):        # yfinance >= 0.2 guard
        df.columns = df.columns.get_level_values(0)
    df = compute_features(df)

    # --- Sentiment (change 2: chunked, also returns article count) ---
    sentiment, news_count = get_daily_sentiment(name)

    # --- Attach today's sentiment to every row ---
    df["Sentiment"] = sentiment

    # --- Build raw feature matrix in the exact same column order as training ---
    raw_features = df[FEATURE_COLS].values.astype(np.float32)

    # --- Change 4: apply the training scaler before feeding to the model ---
    scaled_features = scaler.transform(raw_features)

    # --- LSTM forward pass ---
    seq = build_sequence(scaled_features)
    with torch.no_grad():
        pred = model(seq).item()

    signal = get_trade_signal(pred, sentiment)

    # --- Collect result (change 5: article count added as supplementary context) ---
    report.append({
        "Stock":         ticker,
        "Pred Return":   round(pred,      6),
        "Sentiment":     round(sentiment, 4),
        "News Articles": news_count,
        "Signal":        signal,
    })
# Out:
# Processing AAPL …
# [*********************100%***********************]  1 of 1 completed
# Token indices sequence length is longer than the specified maximum sequence length for this model (2056 > 512). Running this sequence through the model will result in indexing errors
# Processing MSFT …
# [*********************100%***********************]  1 of 1 completed
# Processing GOOGL …
# [*********************100%***********************]  1 of 1 completed
# Processing NVDA …
# [*********************100%***********************]  1 of 1 completed
# Processing TSLA …
# [*********************100%***********************]  1 of 1 completed

# %% [markdown]
# ## Report

# %%
report_df = pd.DataFrame(report)
report_df
# Out:
#    Stock  Pred Return  Sentiment  News Articles Signal
# 0   AAPL     0.004828     0.6923             19    BUY
# 1   MSFT     0.000188     0.6193             19   HOLD
# 2  GOOGL    -0.003667     0.5369             18   HOLD
# 3   NVDA     0.095112     0.7757             20    BUY
# 4   TSLA     0.011896     0.6630             20    BUY
